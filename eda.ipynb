# %% [markdown]
# # Pokemon Stats Data Analysis
#
# In main series pokemon games, kids and adults alike catch pokemon and battle gym leaders to become pokemon master! With over 800 pokemon in some games, the team combinations and strategies are limitless. You must understand a pokemon stats to predict how they will perform in battle and to create a powerful team. I have obatined data on all pokemons stats from Genration 1 to Genration 6 or the `Pokemon X` and `Pokemon Y` games that came out in October 12, 2013 on the Nintendo 3ds. The goal of my project is to analyze the data within the Pokemon Stats csv, and determine what top 10 pokemon have the best total stats in each generation. This analysis will help even the most novice of players make the best team no matter what generation they are playing.

# %% [markdown]
# ![](images/pokemon_johto.gif)

# %% [markdown]
# ## Fields in My Dataset
#
# Kaggle publishes downloadable files of Pokemon stats data. This data includes:
#
# * Name
# * Type 1 (All Pokemon will have a type in this field)
# * Type 2 (Some Pokemon may have two types and the second one will populate here)
# * Total (Total Base Stats of the Pokemon)
# * HP
# * Attack (Stat for physical attacks)
# * Defense (Stat for defending against physical attacks)
# * Sp. Atk (Stat for non-physical attacks ex:shooting a blast at a pokemon)
# * Sp. Def (Stat for defending against special attacks)
# * Speed
# * Generation
# * Legendary

# %% [markdown]
# ## Downloading My Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (9, 8)
plt.rcParams['font.size'] = 12
pkmn = pd.read_csv('data/Pokemon.csv')
pkmn.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# Before diving any deeper into the data and cleaning it I wanted to first setup the index as `#` instead of the one Pandas provided.

# %%
pkmn.set_index('#', inplace=True)
pkmn.head(3)
# Out:
#         Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# #
# 1     45           1      False
# 2     60           1      False
# 3     80           1      False

# %% [markdown]
# I then wanted to see how many rows and columns were in my data. Below are the results.

# %%
pkmn.shape
# Out:
# (800, 12)

# %% [markdown]
# ## Scrubbing My Data
#
# When cleaning my data I wanted to first see how many null values were present.

# %%
pkmn.isnull().sum()
# Out:
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# From my analysis, the only field that had null values was the `Type 2` field.
# This was to be expected since not all pokemon have 2 types.

# %% [markdown]
# After discovering that I counted the the number of unique values that were in the `Type 2` column. I knew I was going to run into issues with the `Type 2` column having a space, so I replaced the space in all my columns with `_`.

# %%
pkmn.columns = pkmn.columns.str.replace(' ', '_')
pkmn.Type_2.value_counts(dropna=False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Water        14
# Ghost        14
# Ice          14
# Rock         14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type_2, dtype: int64

# %% [markdown]
# I then replaced the missing values with the string value `NoType`

# %%
pkmn['Type_2'].fillna(value='NoType').head(10)
# Out:
# #
# 1    Poison
# 2    Poison
# 3    Poison
# 3    Poison
# 4    NoType
# 5    NoType
# 6    Flying
# 6    Dragon
# 6    Flying
# 7    NoType
# Name: Type_2, dtype: object

# %%
pkmn.fillna(value={'Type_2': 'NoType'}, inplace=True)
pkmn.head(10)
# Out:
#                         Name Type_1  Type_2  Total  HP  Attack  Defense  \
# #
# 1                  Bulbasaur  Grass  Poison    318  45      49       49
# 2                    Ivysaur  Grass  Poison    405  60      62       63
# 3                   Venusaur  Grass  Poison    525  80      82       83
# 3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                 Charmander   Fire  NoType    309  39      52       43
# 5                 Charmeleon   Fire  NoType    405  58      64       58
# 6                  Charizard   Fire  Flying    534  78      84       78
# 6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 7                   Squirtle  Water  NoType    314  44      48       65
#
#    Sp._Atk  Sp._Def  Speed  Generation  Legendary
# #
# 1       65       65     45           1      False
# 2       80       80     60           1      False
# 3      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 6      130       85    100           1      False
# 6      159      115    100           1      False
# 7       50       64     43           1      False

# %% [markdown]
# ## Removing Legendaries
#
# Legendary Pokemon typically have some of the highest total stats out of all the pokemon in the game. If we were to look at the data as it is now, we would see alot of legedary pokemon being shown with the highest stats. In order to cut down on legendaries showing up, I removed pokemon from the data that had the boolean value of `True` in the `Legendary` column.

# %%
pkmn = pkmn[pkmn.Legendary != True]
pkmn
# Out:
#                       Name  Type_1  Type_2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur   Grass  Poison    318  45      49       49
# 2                  Ivysaur   Grass  Poison    405  60      62       63
# 3                 Venusaur   Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4               Charmander    Fire  NoType    309  39      52       43
# ..                     ...     ...     ...    ...  ..     ...      ...
# 711    GourgeistSuper Size   Ghost   Grass    494  85     100      122
# 712               Bergmite     Ice  NoType    304  55      69       85
# 713                Avalugg     Ice  NoType    514  95     117      184
# 714                 Noibat  Flying  Dragon    245  40      30       35
# 715                Noivern  Flying  Dragon    535  85      70       80
#
#      Sp._Atk  Sp._Def  Speed  Generation  Legendary
# #
# 1         65       65     45           1      False
# 2         80       80     60           1      False
# 3        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 711       58       75     54           6      False
# 712       32       35     28           6      False
# 713       44       46     28           6      False
# 714       45       40     55           6      False
# 715       97       80    123           6      False
#
# [735 rows x 12 columns]

# %% [markdown]
# After doing this I noticed that some legendaries still remained as shown in the example below. You can see the the pokemon Mew is still in our data.

# %%
pkmn.head(161)
# Out:
#                       Name   Type_1  Type_2  Total   HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318   45      49       49
# 2                  Ivysaur    Grass  Poison    405   60      62       63
# 3                 Venusaur    Grass  Poison    525   80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625   80     100      123
# 4               Charmander     Fire  NoType    309   39      52       43
# ..                     ...      ...     ...    ...  ...     ...      ...
# 147                Dratini   Dragon  NoType    300   41      64       45
# 148              Dragonair   Dragon  NoType    420   61      84       65
# 149              Dragonite   Dragon  Flying    600   91     134       95
# 151                    Mew  Psychic  NoType    600  100     100      100
# 152              Chikorita    Grass  NoType    318   45      49       65
#
#      Sp._Atk  Sp._Def  Speed  Generation  Legendary
# #
# 1         65       65     45           1      False
# 2         80       80     60           1      False
# 3        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 147       50       50     50           1      False
# 148       70       70     70           1      False
# 149      100      100     80           1      False
# 151      100      100    100           1      False
# 152       49       65     45           2      False
#
# [161 rows x 12 columns]

# %% [markdown]
# In order to fix this I had to drop the rows I did not want by their index `#`.

# %%
pkmn = pkmn.drop([151, 251, 488, 489, 490, 647, 648, 649])
pkmn.head(161)
#You can see that Mew is now gone
# Out:
#                       Name  Type_1  Type_2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur   Grass  Poison    318  45      49       49
# 2                  Ivysaur   Grass  Poison    405  60      62       63
# 3                 Venusaur   Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4               Charmander    Fire  NoType    309  39      52       43
# ..                     ...     ...     ...    ...  ..     ...      ...
# 147                Dratini  Dragon  NoType    300  41      64       45
# 148              Dragonair  Dragon  NoType    420  61      84       65
# 149              Dragonite  Dragon  Flying    600  91     134       95
# 152              Chikorita   Grass  NoType    318  45      49       65
# 153                Bayleef   Grass  NoType    405  60      62       80
#
#      Sp._Atk  Sp._Def  Speed  Generation  Legendary
# #
# 1         65       65     45           1      False
# 2         80       80     60           1      False
# 3        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 147       50       50     50           1      False
# 148       70       70     70           1      False
# 149      100      100     80           1      False
# 152       49       65     45           2      False
# 153       63       80     60           2      False
#
# [161 rows x 12 columns]

# %% [markdown]
# ## Removing Mega Pokemon
#
# Mega Pokemon are powered up forms of existing pokemon. These forms not only increase the pokemon's stats but it can also add a second `Type` to that pokemon. If we were to look at the data as it is now, we would see alot of mega pokemon being shown with the highest stats since they are on the level of a legendary. In order to cut down on mega pokemon showing up, I removed pokemon from the data that had the string value of `Mega` in the `Name` column.

# %%
pkmn = (pkmn[~pkmn.Name.str.contains("Mega")])
pkmn
# Out:
#                     Name  Type_1  Type_2  Total  HP  Attack  Defense  Sp._Atk  \
# #
# 1              Bulbasaur   Grass  Poison    318  45      49       49       65
# 2                Ivysaur   Grass  Poison    405  60      62       63       80
# 3               Venusaur   Grass  Poison    525  80      82       83      100
# 4             Charmander    Fire  NoType    309  39      52       43       60
# 5             Charmeleon    Fire  NoType    405  58      64       58       80
# ..                   ...     ...     ...    ...  ..     ...      ...      ...
# 711  GourgeistSuper Size   Ghost   Grass    494  85     100      122       58
# 712             Bergmite     Ice  NoType    304  55      69       85       32
# 713              Avalugg     Ice  NoType    514  95     117      184       44
# 714               Noibat  Flying  Dragon    245  40      30       35       45
# 715              Noivern  Flying  Dragon    535  85      70       80       97
#
#      Sp._Def  Speed  Generation  Legendary
# #
# 1         65     45           1      False
# 2         80     60           1      False
# 3        100     80           1      False
# 4         50     65           1      False
# 5         65     80           1      False
# ..       ...    ...         ...        ...
# 711       75     54           6      False
# 712       35     28           6      False
# 713       46     28           6      False
# 714       40     55           6      False
# 715       80    123           6      False
#
# [682 rows x 12 columns]

# %% [markdown]
# ## Generation Breakdown
#
# Now that I have cleaned the data it is time to see who are the top 10 pokemon with the highest stats. I wnated to first do this by each genration and then do it for all the genrations combined.

# %% [markdown]
# ## Generation 1

# %%
gen1 = pkmn[pkmn.Generation == 1]
gen1_top10 = gen1.nlargest(10, ['Total'])
gen1_top10.head(10).plot(x='Name', y='Total', kind='barh', stacked=True)
gen1_top10
# Out:
#           Name  Type_1  Type_2  Total   HP  Attack  Defense  Sp._Atk  Sp._Def  \
# #
# 149  Dragonite  Dragon  Flying    600   91     134       95      100      100
# 59    Arcanine    Fire  NoType    555   90     110       80      100       80
# 130   Gyarados   Water  Flying    540   95     125       79       60      100
# 143    Snorlax  Normal  NoType    540  160     110       65       65      110
# 131     Lapras   Water     Ice    535  130      85       80       85       95
# 6    Charizard    Fire  Flying    534   78      84       78      109       85
# 9    Blastoise   Water  NoType    530   79      83      100       85      105
# 3     Venusaur   Grass  Poison    525   80      82       83      100      100
# 91    Cloyster   Water     Ice    525   50      95      180       85       45
# 134   Vaporeon   Water  NoType    525  130      65       60      110       95
#
#      Speed  Generation  Legendary
# #
# 149     80           1      False
# 59      95           1      False
# 130     81           1      False
# 143     30           1      False
# 131     60           1      False
# 6      100           1      False
# 9       78           1      False
# 3       80           1      False
# 91      70           1      False
# 134     65           1      False

# %% [markdown]
# ## Generation 2

# %%
gen2 = pkmn[pkmn.Generation == 2]
gen2_top10 = gen2.nlargest(10, ['Total'])
gen2_top10.head(10).plot(x='Name', y='Total', kind='barh', stacked=True)
gen2_top10
# Out:
#            Name    Type_1  Type_2  Total   HP  Attack  Defense  Sp._Atk  \
# #
# 248   Tyranitar      Rock    Dark    600  100     134      110       95
# 230     Kingdra     Water  Dragon    540   75      95       95       95
# 242     Blissey    Normal  NoType    540  255      10       10       75
# 169      Crobat    Poison  Flying    535   85      90       80       70
# 157  Typhlosion      Fire  NoType    534   78      84       78      109
# 160  Feraligatr     Water  NoType    530   85     105      100       79
# 196      Espeon   Psychic  NoType    525   65      65       60      130
# 197     Umbreon      Dark  NoType    525   95      65      110       60
# 233    Porygon2    Normal  NoType    515   85      80       90      105
# 181    Ampharos  Electric  NoType    510   90      75       85      115
#
#      Sp._Def  Speed  Generation  Legendary
# #
# 248      100     61           2      False
# 230       95     85           2      False
# 242      135     55           2      False
# 169       80    130           2      False
# 157       85    100           2      False
# 160       83     78           2      False
# 196       95    110           2      False
# 197      130     65           2      False
# 233       95     60           2      False
# 181       90     55           2      False

# %% [markdown]
# ## Generation 3

# %%
gen3 = pkmn[pkmn.Generation == 3]
gen3_top10 = gen3.nlargest(10, ['Total'])
gen3_top10.head(10).plot(x='Name', y='Total', kind='barh', stacked=True)
gen3_top10
# Out:
#           Name  Type_1    Type_2  Total   HP  Attack  Defense  Sp._Atk  \
# #
# 289    Slaking  Normal    NoType    670  150     160      100       95
# 373  Salamence  Dragon    Flying    600   95     135       80      110
# 376  Metagross   Steel   Psychic    600   80     135      130       95
# 350    Milotic   Water    NoType    540   95      60       79      100
# 260   Swampert   Water    Ground    535  100     110       90       85
# 254   Sceptile   Grass    NoType    530   70      85       65      105
# 257   Blaziken    Fire  Fighting    530   80     120       70      110
# 306     Aggron   Steel      Rock    530   70     110      180       60
# 365    Walrein     Ice     Water    530  110      80       90       95
# 330     Flygon  Ground    Dragon    520   80     100       80       80
#
#      Sp._Def  Speed  Generation  Legendary
# #
# 289       65    100           3      False
# 373       80    100           3      False
# 376       90     70           3      False
# 350      125     81           3      False
# 260       90     60           3      False
# 254       85    120           3      False
# 257       70     80           3      False
# 306       60     50           3      False
# 365       90     65           3      False
# 330       80    100           3      False

# %% [markdown]
# ## Generation 4

# %%
gen4 = pkmn[pkmn.Generation == 4]
gen4_top10 = gen4.nlargest(10, ['Total'])
gen4_top10.head(10).plot(x='Name', y='Total', kind='barh', stacked=True)
gen4_top10
# Out:
#            Name    Type_1    Type_2  Total   HP  Attack  Defense  Sp._Atk  \
# #
# 445    Garchomp    Dragon    Ground    600  108     130       95       80
# 468    Togekiss     Fairy    Flying    545   85      50       95      120
# 466  Electivire  Electric    NoType    540   75     123       67       95
# 467   Magmortar      Fire    NoType    540   75      95       67      125
# 462   Magnezone  Electric     Steel    535   70      70      115      130
# 464   Rhyperior    Ground      Rock    535  115     140      130       55
# 465   Tangrowth     Grass    NoType    535  100     100      125      110
# 474   Porygon-Z    Normal    NoType    535   85      80       70      135
# 392   Infernape      Fire  Fighting    534   76     104       71      104
# 395    Empoleon     Water     Steel    530   84      86       88      111
#
#      Sp._Def  Speed  Generation  Legendary
# #
# 445       85    102           4      False
# 468      115     80           4      False
# 466       85     95           4      False
# 467       95     83           4      False
# 462       90     60           4      False
# 464       55     40           4      False
# 465       50     50           4      False
# 474       75     90           4      False
# 392       71    108           4      False
# 395      101     60           4      False

# %% [markdown]
# ## Generation 5

# %%
gen5 = pkmn[pkmn.Generation == 5]
gen5_top10 = gen5.nlargest(10, ['Total'])
gen5_top10.head(10).plot(x='Name', y='Total', kind='barh', stacked=True)
gen5_top10
# Out:
#                    Name  Type_1    Type_2  Total   HP  Attack  Defense  \
# #
# 635           Hydreigon    Dark    Dragon    600   92     105       90
# 567            Archeops    Rock    Flying    567   75     140       65
# 637           Volcarona     Bug      Fire    550   85      60       65
# 555  DarmanitanZen Mode    Fire   Psychic    540  105      30      105
# 612             Haxorus  Dragon    NoType    540   76     147       90
# 584           Vanilluxe     Ice    NoType    535   71      95       85
# 497           Serperior   Grass    NoType    528   75      75       95
# 500              Emboar    Fire  Fighting    528  110     123       65
# 503            Samurott   Water    NoType    528   95     100       85
# 601           Klinklang   Steel    NoType    520   60     100      115
#
#      Sp._Atk  Sp._Def  Speed  Generation  Legendary
# #
# 635      125       90     98           5      False
# 567      112       65    110           5      False
# 637      135      105    100           5      False
# 555      140      105     55           5      False
# 612       60       70     97           5      False
# 584      110       95     79           5      False
# 497       75       95    113           5      False
# 500      100       65     65           5      False
# 503      108       70     70           5      False
# 601       70       85     90           5      False

# %% [markdown]
# ## Generation 6

# %%
gen6 = pkmn[pkmn.Generation == 6]
gen6_top10 = gen6.nlargest(10, ['Total'])
gen6_top10.head(10).plot(x='Name', y='Total', kind='barh', stacked=True)
gen6_top10
# Out:
#            Name  Type_1    Type_2  Total   HP  Attack  Defense  Sp._Atk  \
# #
# 706      Goodra  Dragon    NoType    600   90     100       70      110
# 671     Florges   Fairy    NoType    552   78      65       68      112
# 715     Noivern  Flying    Dragon    535   85      70       80       97
# 655     Delphox    Fire   Psychic    534   75      69       72      114
# 673      Gogoat   Grass    NoType    531  123     100       62       97
# 652  Chesnaught   Grass  Fighting    530   88     107      122       74
# 658    Greninja   Water      Dark    530   72      95       67      103
# 700     Sylveon   Fairy    NoType    525   95      65       65      110
# 697   Tyrantrum    Rock    Dragon    521   82     121      119       69
# 699     Aurorus    Rock       Ice    521  123      77       72       99
#
#      Sp._Def  Speed  Generation  Legendary
# #
# 706      150     80           6      False
# 671      154     75           6      False
# 715       80    123           6      False
# 655      100    104           6      False
# 673       81     68           6      False
# 652       75     64           6      False
# 658       71    122           6      False
# 700      130     60           6      False
# 697       59     71           6      False
# 699       92     58           6      False

# %% [markdown]
# ## All Generations

# %%
gen_all = pkmn.nlargest(10, ['Total'])
gen_all.head(10).plot(x='Name', y='Total', kind='barh', stacked=True)
gen_all
# Out:
#           Name  Type_1   Type_2  Total   HP  Attack  Defense  Sp._Atk  \
# #
# 289    Slaking  Normal   NoType    670  150     160      100       95
# 149  Dragonite  Dragon   Flying    600   91     134       95      100
# 248  Tyranitar    Rock     Dark    600  100     134      110       95
# 373  Salamence  Dragon   Flying    600   95     135       80      110
# 376  Metagross   Steel  Psychic    600   80     135      130       95
# 445   Garchomp  Dragon   Ground    600  108     130       95       80
# 635  Hydreigon    Dark   Dragon    600   92     105       90      125
# 706     Goodra  Dragon   NoType    600   90     100       70      110
# 567   Archeops    Rock   Flying    567   75     140       65      112
# 59    Arcanine    Fire   NoType    555   90     110       80      100
#
#      Sp._Def  Speed  Generation  Legendary
# #
# 289       65    100           3      False
# 149      100     80           1      False
# 248      100     61           2      False
# 373       80    100           3      False
# 376       90     70           3      False
# 445       85    102           4      False
# 635       90     98           5      False
# 706      150     80           6      False
# 567       65    110           5      False
# 59        80     95           1      False

# %% [markdown]
# ###                                             We are done!  Now go catch em all!!!

# %% [markdown]
# ![](images/drake.gif)
